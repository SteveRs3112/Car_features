# %%
import pandas as pd

# %%
data = pd.read_csv('chemin_vers_votre_fichier/nom_de_votre_fichier.data', delimiter=',')

# %%
pd.read_csv('fichier.csv', usecols=['nom', 'age', 'ville'])

# %%
titre = ['symboling', 'normalized-losses', 'make','fuel-type','aspiration','num-of-doors','body-style','drive-wheels','engine-location','wheel-base','length','width','height','curb-height','engine-type','num-of-cylinders','engine-size','fuel-system','bore','stroke','compression-ratio','horsepower','peak-rpm','city-mpg','highway-mpg','price']

# %%
data = pd.read_csv('imports-85.data', names= titre)

# %%
data.head(50)
# Out:
#     symboling normalized-losses         make fuel-type aspiration  \
# 0           3                 ?  alfa-romero       gas        std
# 1           3                 ?  alfa-romero       gas        std
# 2           1                 ?  alfa-romero       gas        std
# 3           2               164         audi       gas        std
# 4           2               164         audi       gas        std
# 5           2                 ?         audi       gas        std
# 6           1               158         audi       gas        std
# 7           1                 ?         audi       gas        std
# 8           1               158         audi       gas      turbo
# 9           0                 ?         audi       gas      turbo
# 10          2               192          bmw       gas        std
# 11          0               192          bmw       gas        std
# 12          0               188          bmw       gas        std
# ...

# %%
data = data.dropna(axis=0)

# %%
data['normalized-losses'] = data['normalized-losses'].replace({'NaN': np.nan, '??': np.nan})

# %%
data['price'] = data['price'].replace({'NaN': np.nan, '??': np.nan})

# %%
data = data.dropna()

# %%
import pandas as pd
import numpy as np

# %%
import pandas as pd
import numpy as np

# créer un DataFrame avec des valeurs NaN
df = pd.DataFrame({'A': [1, 2, np.nan, 4], 'B': [5, np.nan, 7, 8], 'C': [9, 10, 11, 12]})

# enlever les lignes qui contiennent des NaN
df = df.dropna()

# %%
data = data.dropna()

# %%
data.head(50)
# Out:
#     symboling normalized-losses           make fuel-type aspiration  \
# 3           2               164           audi       gas        std
# 4           2               164           audi       gas        std
# 6           1               158           audi       gas        std
# 8           1               158           audi       gas      turbo
# 10          2               192            bmw       gas        std
# 11          0               192            bmw       gas        std
# 12          0               188            bmw       gas        std
# 13          0               188            bmw       gas        std
# 18          2               121      chevrolet       gas        std
# 19          1                98      chevrolet       gas        std
# 20          0                81      chevrolet       gas        std
# 21          1               118          dodge       gas        std
# 22          1               118          dodge       gas        std
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    object
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       205 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-height        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
# ...

# %%
data.isnull().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-height          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
data.head()
# Out:
#     symboling normalized-losses  make fuel-type aspiration num-of-doors  \
# 3           2               164  audi       gas        std         four
# 4           2               164  audi       gas        std         four
# 6           1               158  audi       gas        std         four
# 8           1               158  audi       gas      turbo         four
# 10          2               192   bmw       gas        std          two
#
#    body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 3       sedan          fwd           front        99.8  ...          109
# 4       sedan          4wd           front        99.4  ...          136
# 6       sedan          fwd           front       105.8  ...          136
# 8       sedan          fwd           front       105.8  ...          131
# 10      sedan          rwd           front       101.2  ...          108
#
#     fuel-system  bore  stroke compression-ratio horsepower  peak-rpm city-mpg  \
# ...

# %%
data_cleaned = data.drop(['make','fuel-type','aspiration','num-of-doors','body-style','drive-wheels','engine-location','fuel-system'],axis=1)

# %%
data_cleaned = data_cleaned.drop(['engine-type','num-of-cylinders','bore','stroke','compression-ratio'],axis=1)

# %%
data_cleaned.head()
# Out:
#     symboling normalized-losses  wheel-base  length  width  height  \
# 3           2               164        99.8   176.6   66.2    54.3
# 4           2               164        99.4   176.6   66.4    54.3
# 6           1               158       105.8   192.7   71.4    55.7
# 8           1               158       105.8   192.7   71.4    55.9
# 10          2               192       101.2   176.8   64.8    54.3
#
#     curb-height  engine-size horsepower peak-rpm  city-mpg  highway-mpg  price
# 3          2337          109        102     5500        24           30  13950
# 4          2824          136        115     5500        18           22  17450
# 6          2844          136        110     5500        19           25  17710
# 8          3086          131        140     5500        17           20  23875
# 10         2395          108        101     5800        23           29  16430

# %%
data_cleaned = data_cleaned.astype(float)

# %%
data_cleaned.tail(50)
# Out:
#      symboling  normalized-losses  wheel-base  length  width  height  \
# 150        1.0               87.0        95.7   158.7   63.6    54.5
# 151        1.0               87.0        95.7   158.7   63.6    54.5
# 152        1.0               74.0        95.7   158.7   63.6    54.5
# 153        0.0               77.0        95.7   169.7   63.6    59.1
# 154        0.0               81.0        95.7   169.7   63.6    59.1
# 155        0.0               91.0        95.7   169.7   63.6    59.1
# 156        0.0               91.0        95.7   166.3   64.4    53.0
# 157        0.0               91.0        95.7   166.3   64.4    52.8
# 158        0.0               91.0        95.7   166.3   64.4    53.0
# 159        0.0               91.0        95.7   166.3   64.4    52.8
# 160        0.0               91.0        95.7   166.3   64.4    53.0
# 161        0.0               91.0        95.7   166.3   64.4    52.8
# 162        0.0               91.0        95.7   166.3   64.4    52.8
# ...

# %%
data_cleaned = data_cleaned.drop(['symboling'],axis=1)

# %%
price = data_cleaned['price']

# %%
price.head(50)
# Out:
# 3     13950.0
# 4     17450.0
# 6     17710.0
# 8     23875.0
# 10    16430.0
# 11    16925.0
# 12    20970.0
# 13    21105.0
# 18     5151.0
# 19     6295.0
# 20     6575.0
# 21     5572.0
# 22     6377.0
# 23     7957.0
# 24     6229.0
# 25     6692.0
# 26     7609.0
# 27     8558.0
# 28     8921.0
# 29    12964.0
# 30     6479.0
# 31     6855.0
# 32     5399.0
# 33     6529.0
# 34     7129.0
# 35     7295.0
# 36     7295.0
# 37     7895.0
# 38     9095.0
# 39     8845.0
# 40    10295.0
# 41    12945.0
# 42    10345.0
# 47    32250.0
# 50     5195.0
# 51     6095.0
# 52     6795.0
# 53     6695.0
# 54     7395.0
# 55    10945.0
# 56    11845.0
# 57    13645.0
# 58    15645.0
# 59     8845.0
# 60     8495.0
# 61    10595.0
# 62    10245.0
# 64    11245.0
# 65    18280.0
# 67    25552.0
# Name: price, dtype: float64

# %%
data

# %%
moyenne_data_cleaned = data_cleaned.mean()
